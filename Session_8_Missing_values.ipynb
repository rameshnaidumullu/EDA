# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = {'Names':['Ramesh','Suresh','Mahesh',np.nan],
       'City':['Hyd','Vizag',np.nan,'vij'],
       'Age':[np.nan,22,23,24]}
df=pd.DataFrame(Data)
df
# Out:
#     Names   City   Age
# 0  Ramesh    Hyd   NaN
# 1  Suresh  Vizag  22.0
# 2  Mahesh    NaN  23.0
# 3     NaN    vij  24.0

# %%
Data = {'Names':['Ramesh','Suresh','Mahesh',None],
       'City':['Hyd','Vizag',None,'vij'],
       'Age':[None,22,23,24]}
df=pd.DataFrame(Data)
df
# Out:
#     Names   City   Age
# 0  Ramesh    Hyd   NaN
# 1  Suresh  Vizag  22.0
# 2  Mahesh   None  23.0
# 3    None    vij  24.0

# %%
df.to_csv('data_missing.csv',index=False)

# %%
pd.read_csv('data_missing.csv')
# Out:
#     Names   City   Age
# 0  Ramesh    Hyd   NaN
# 1  Suresh  Vizag  22.0
# 2  Mahesh    NaN  23.0
# 3     NaN    vij  24.0

# %%
df.dtypes
# Out:
# Names     object
# City      object
# Age      float64
# dtype: object

# %%
df.isnull()
# Out:
#    Names   City    Age
# 0  False  False   True
# 1  False  False  False
# 2  False   True  False
# 3   True  False  False

# %%
df.isnull().sum()
# Out:
# Names    1
# City     1
# Age      1
# dtype: int64

# %% [markdown]
# **filna**

# %%
df.fillna(30)
# Out:
#     Names   City   Age
# 0  Ramesh    Hyd  30.0
# 1  Suresh  Vizag  22.0
# 2  Mahesh     30  23.0
# 3      30    vij  24.0

# %%
df['Age'].fillna(30)
# Out:
# 0    30.0
# 1    22.0
# 2    23.0
# 3    24.0
# Name: Age, dtype: float64

# %%
arr1 = np.array([1,2,np.nan,3])
arr2 = np.array([1,2,None,3])

# %%
arr1
# Out:
# array([ 1.,  2., nan,  3.])

# %%
arr2
# Out:
# array([1, 2, None, 3], dtype=object)

# %%
np.nansum(arr1),np.sum(arr1)
# Out:
# (np.float64(6.0), np.float64(nan))

# %%
np.nansum(arr2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 np.nansum(arr2)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:744, in nansum(a, axis, dtype, out, keepdims, initial, where)
#     647 """
#     648 Return the sum of array elements over a given axis treating Not a
#     649 Numbers (NaNs) as zero.
#    (...)
#     741
#     742 """
#     743 a, mask = _replace_nan(a, 0)
# --> 744 return np.sum(a, axis=axis, dtype=dtype, out=out, keepdims=keepdims,
#     745               initial=initial, where=where)
#
# File ~\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:2485, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2482         return out
#    2483     return res
# -> 2485 return _wrapreduction(
#    2486     a, np.add, 'sum', axis, dtype, out,
#    2487     keepdims=keepdims, initial=initial, where=where
#    2488 )
#
# File ~\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
df['Names'].fillna("ram")
# Out:
# 0    Ramesh
# 1    Suresh
# 2    Mahesh
# 3       ram
# Name: Names, dtype: object

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='pad')
# Out:
#     Names   City   Age
# 0  Ramesh    Hyd   NaN
# 1  Suresh  Vizag  22.0
# 2  Mahesh  Vizag  23.0
# 3  Mahesh    vij  24.0

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='bfill')
# Out:
#     Names   City   Age
# 0  Ramesh    Hyd  22.0
# 1  Suresh  Vizag  22.0
# 2  Mahesh    vij  23.0
# 3    None    vij  24.0

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='ffill')
# Out:
#     Names   City   Age
# 0  Ramesh    Hyd   NaN
# 1  Suresh  Vizag  22.0
# 2  Mahesh  Vizag  23.0
# 3  Mahesh    vij  24.0

# %%
import warnings
warnings.filterwarnings('ignore')
df.fillna(method='backfill')
# Out:
#     Names   City   Age
# 0  Ramesh    Hyd  22.0
# 1  Suresh  Vizag  22.0
# 2  Mahesh    vij  23.0
# 3    None    vij  24.0

# %%
age_median = df['Age'].median()

# %%
df['Age'].mean()
# Out:
# np.float64(23.0)

# %%
df['Age'].fillna(age_median)
# Out:
# 0    23.0
# 1    22.0
# 2    23.0
# 3    24.0
# Name: Age, dtype: float64

# %%
df['City'].mode()
# Out:
# 0      Hyd
# 1    Vizag
# 2      vij
# Name: City, dtype: object

# %%
import numpy as np
from sklearn.impute import KNNImputer

# %%
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.impute import KNNImputer

# %%
x = [[1,2,np.nan],[3,np.nan,3],[np.nan,60,5],[8,8,7]]
pd.DataFrame(x)
# Out:
#      0     1    2
# 0  1.0   2.0  NaN
# 1  3.0   NaN  3.0
# 2  NaN  60.0  5.0
# 3  8.0   8.0  7.0

# %%
imputer = KNNImputer(n_neighbors=2, weights='uniform')
imputer.fit_transform(x)
# Out:
# array([[ 1. ,  2. ,  5. ],
#        [ 3. , 31. ,  3. ],
#        [ 5.5, 60. ,  5. ],
#        [ 8. ,  8. ,  7. ]])
