# %% [markdown]
# **Step-1:create a folder using python code**

# %%
import os
try:
    os.makedirs('freqency_table')
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'freqency_table'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# os.makedirs('freqency_table',exist_ok=True)

# %%
continent_keys=visa_df['continent'].value_counts().keys()
continent_values=visa_df['continent'].value_counts().values
continent_df = pd.DataFrame(zip(continent_keys,continent_values),columns=['keys','values'])
path = r"C:\Users\SAI SUDHEER\Documents\NareshIT\Dataframes\freqency_table\continent.csv"
continent_df.to_csv(path,index=False)

# %%
path = 'Visadataset.csv'
visa_df = pd.read_csv(path)
visa_df
cat = visa_df.select_dtypes(include = 'object').columns
num = visa_df.select_dtypes(exclude = 'object').columns
visa_df['continent'].values
con = visa_df['continent']=='Asia'
len(visa_df[con])
label = visa_df['continent'].unique()
count = []
for i in label:
    con = visa_df['continent']==i
    count.append(len(visa_df[con]))
count
continent_df=pd.DataFrame(zip(label,count),columns = ['continent','count'])
#continent_df.to_csv('continent_df.csv',index=False)

# %%
path = r".\freqency_table\continent1.csv"
continent_df.to_csv(path,index=False)

# %%
cwd=os.getcwd()
folder_name = 'freqency_table'
new_dir=os.path.join(cwd,folder_name)
file_name='continent2.csv'
path = os.path.join(new_dir,file_name)
continent_df.to_csv(path,index=False)

# %%
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    df = pd.DataFrame(zip(keys,values),columns=['keys','values'])
    #step-2
    folder_name = 'freqency_table'
    os.makedirs(folder_name,exist_ok=True)
    #step-3
    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.csv'
    path = os.path.join(new_dir,file_name)
    #step-4
    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.csv'
    path = os.path.join(new_dir,file_name)
    df.to_csv(path,index=False)

# %%
#step-1
for i in cat:
    keys=visa_df[i].value_counts().keys()
    values=visa_df[i].value_counts().values
    df = pd.DataFrame(zip(keys,values),columns=['keys','values'])
    #step-2
    folder_name = 'freqency_table'
    os.makedirs(folder_name,exist_ok=True)
    #step-3
    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.csv'
    path = os.path.join(new_dir,file_name)
    #step-4
    df.to_csv(path,index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #step-1
# ----> 2 for i in cat:
#       3     keys=visa_df[i].value_counts().keys()
#       4     values=visa_df[i].value_counts().values
#
# NameError: name 'cat' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
path = 'global air pollution dataset.csv'
gobal_df = pd.read_csv(path)

cat = gobal_df.select_dtypes(include = 'object').columns
num = gobal_df.select_dtypes(exclude = 'object').columns

gobal_df['AQI Category'].values
con = gobal_df['AQI Category']=='Good'
len(gobal_df[con])

labels = gobal_df['AQI Category'].unique()
count = []
for i in labels:
    con = gobal_df['AQI Category']==i
    count.append(len(gobal_df[con]))
count    
Air_df=pd.DataFrame(zip(labels,count),columns = ['labels','count'])
Air_df.to_csv('Air.csv',index=False)

# %%
import os
    
keys=gobal_df[i].value_counts().keys()
values = gobal_df[i].value_counts().values
df = pd.DataFrame(zip(keys,values),columns=['Keys','values'])

folder_name ="GobalData" 
os.makedirs(folder_name,exist_ok = True)

cwd = os.getcwd()
new_dirs = os.path.join(cwd,folder_name)
file_name=f'{i}.csv'
path = os.path.join(new_dirs,file_name)

df.to_csv(path,index=False)

# %%
for i in cat:
    keys=gobal_df[i].value_counts().keys()
    values = gobal_df[i].value_counts().values
    df = pd.DataFrame(zip(keys,values),columns=['Keys','values'])
    
    folder_name ="GobalData" 
    os.makedirs(folder_name,exist_ok = True)
    
    cwd = os.getcwd()
    new_dirs = os.path.join(cwd,folder_name)
    file_name=f'{i}.csv'
    path = os.path.join(new_dirs,file_name)
    
    df.to_csv(path,index=False)

# %% [markdown]
# **Bar chart Automate**

# %%
 num
# Out:
# Index(['AQI Value', 'CO AQI Value', 'Ozone AQI Value', 'NO2 AQI Value',
#        'PM2.5 AQI Value'],
#       dtype='object')

# %%
import os
for i in num:
    keys=gobal_df[i].value_counts().keys()                                             
    values = gobal_df[i].value_counts().values
    
    plt.figure(figsize=(10,4))
    plt.bar(keys,values)

    folder_name = 'Bar_chart_gobal'
    os.makedirs(folder_name,exist_ok=True)
    #step-3

    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.jpg'
    path = os.path.join(new_dir,file_name)
    
    plt.savefig(path)

# %%
keys = visa_df['continent'].value_counts().keys()
values = visa_df['continent'].value_counts().values
plt.figure(figsize=(10,4))
plt.bar(keys,values)
plt.xlabel('labels')
plt.ylabel('count')
plt.title('continent_bar')
plt.savefig('continent_bar.png')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cat
#
# NameError: name 'cat' is not defined

# %%
cat = visa_df.select_dtypes(include = 'object').columns
num = visa_df.select_dtypes(exclude = 'object').columns
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
import os
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    
    plt.figure(figsize=(10,3))
    plt.bar(keys,values)

    folder_name = 'Bar_chart'
    os.makedirs(folder_name,exist_ok=True)
    #step-3

    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.jpg'
    path = os.path.join(new_dir,file_name)
    
    plt.savefig(path)

# %%
csv_path = r"C:\Users\SAI SUDHEER\Documents\DataFiles\Visadataset.csv"

visa_df = pd.read_csv(csv_path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
for i in cat[1:]:
    keys = visa_df[i].value_counts().keys()
    values = visa_df[i].value_counts().values
    
    
    plt.pie(values,labels=keys,explode=[0.1 for i in range (len(keys))])

    folder_name = 'Pie_chart'
    os.makedirs(folder_name,exist_ok=True)
    #step-3

    cwd=os.getcwd()
    new_dir=os.path.join(cwd,folder_name)
    file_name=f'{i}.jpg'
    path = os.path.join(new_dir,file_name)
    
    plt.savefig(path)

# %%
path = 'Visadataset.csv'
visa_df = pd.read_csv(path)
visa_df
cat = visa_df.select_dtypes(include = 'object').columns
num = visa_df.select_dtypes(exclude = 'object').columns

# %%
keys = visa_df['continent'].value_counts().keys()
values = visa_df['continent'].value_counts().values
plt.figure(figsize=(10,4))
plt.bar(keys,values)
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# **Subplot**

# %%
plt.subplot(2,2,1)
plt.title('2-2-1')
plt.subplot(2,2,2)
plt.title('2-2-2')
plt.subplot(2,2,3)
plt.title('2-2-3')
plt.subplot(2,2,4)
plt.title('2-2-4')
# Out:
# Text(0.5, 1.0, '2-2-4')

# %%
plt.subplot(1,3,1)
plt.subplot(1,3,2)
plt.subplot(1,3,3)
# Out:
# <Axes: >

# %%
plt.subplot(3,1,1)
plt.subplot(3,1,2)
plt.subplot(3,1,3)
# Out:
# <Axes: >

# %%
#plt.subplot(2,2,1)
#plt.subplot(2,2,2)
#plt.subplot(2,2,3)
#plt.subplot(2,2,4)
for i in range(1,5):
    plt.subplot(2,2,i)

# %%
for i in range(1,10):
    plt.subplot(3,3,i)

# %%
 plt.figure(figsize=(16,8))
for i in range(1,len(cat)):
    keys = visa_df[cat[i]].value_counts().keys()
    values = visa_df[cat[i]].value_counts().values
   
    plt.subplot(3,3,i)
    plt.bar(keys,values)
    plt.title(f"{cat[i]}")
    plt.suptitle("Bar chart")
